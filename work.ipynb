# %%
from PIL import Image
import torch
from diffusers import DiffusionPipeline
from matplotlib import pyplot as plt

# %%
pipeline = DiffusionPipeline.from_pretrained("stabilityai/stable-diffusion-xl-base-1.0").to('cuda')
# Out:
# Loading pipeline components...: 100%|██████████| 7/7 [00:00<00:00,  7.30it/s]

# %%
image, xt_list_, prompt_embeds, mid_ = pipeline("little kitten playing with a red ball", neg_prompt="", 
                                                num_inference_steps=30,
                                                # guidance_scale=guidance_scale,
                                                generator=torch.manual_seed(111),
                                                oneactor_save=True)
# Out:
# 100%|██████████| 30/30 [00:19<00:00,  1.55it/s]

# %%
plt.imshow(image[-1][0])

# %%
im = Image.open('output/demo/a_young_woman_with_long_wavy_hair_wairing_sundress_photo_realistic/inference/OneActor_leaning_on_a_fence_step_120.jpg')

# %%
plt.imshow(im)
